# %% [markdown]
# # 1. Create a CNN model for binary class problems.

# %%
import tensorflow
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img,img_to_array,load_img
import matplotlib as mt
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
# Out:
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Create an image instance of the ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.2,
    zoom_range=0.2,
    rescale=1./255,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)
print('training length:\n')
batch_size = 16
train_data = train_datagen.flow_from_directory(
    'C:/Users/hp/dataset/train',
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='binary'
)
print()
print('training length:\n')
test_data = test_datagen.flow_from_directory(
    'C:/Users/hp/dataset/test',  
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# training length:
#
# Found 840 images belonging to 2 classes.
#
# training length:
#
# Found 188 images belonging to 2 classes.

# %%
model = Sequential()

# 1st convolution layer
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# 2nd convolution layer
model.add(Conv2D(64, (3, 3),input_shape=(150,150,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# 3rd convolution layer
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# Converting multi-dimensional to 1D array
model.add(Flatten())
model.add(Dense(units=150, activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 32)        18464
#
#  max_pooling2d_5 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9248)              0
#
#  dense_2 (Dense)             (None, 150)               1387350
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_3 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 1425357 (5.44 MB)
# Trainable params: 1425357 (5.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
result=model.fit(train_data,
                 steps_per_epoch=48//batch_size,epochs=30,
                 validation_data=test_data,
                 validation_steps=48//batch_size
                )
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 10s 2s/step - loss: 0.7338 - accuracy: 0.6250 - val_loss: 0.6963 - val_accuracy: 0.4792
# Epoch 2/30
# 3/3 [==============================] - 4s 2s/step - loss: 0.7061 - accuracy: 0.4792 - val_loss: 0.6874 - val_accuracy: 0.5417
# Epoch 3/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.7011 - accuracy: 0.3750 - val_loss: 0.6916 - val_accuracy: 0.5625
# Epoch 4/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6907 - accuracy: 0.5833 - val_loss: 0.7044 - val_accuracy: 0.4583
# Epoch 5/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.7021 - accuracy: 0.4375 - val_loss: 0.6926 - val_accuracy: 0.5417
# Epoch 6/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6942 - accuracy: 0.4167 - val_loss: 0.6932 - val_accuracy: 0.5208
# Epoch 7/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6911 - accuracy: 0.5833 - val_loss: 0.6899 - val_accuracy: 0.6250
# Epoch 8/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6913 - accuracy: 0.4583 - val_loss: 0.6867 - val_accuracy: 0.6875
# Epoch 9/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6900 - accuracy: 0.5625 - val_loss: 0.6875 - val_accuracy: 0.5625
# Epoch 10/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6957 - accuracy: 0.4583 - val_loss: 0.6809 - val_accuracy: 0.6458
# Epoch 11/30
# 3/3 [==============================] - 2s 974ms/step - loss: 0.6993 - accuracy: 0.4167 - val_loss: 0.6911 - val_accuracy: 0.4583
# Epoch 12/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6937 - accuracy: 0.5208 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 13/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6942 - accuracy: 0.5750 - val_loss: 0.6971 - val_accuracy: 0.3958
# Epoch 14/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6965 - accuracy: 0.3750 - val_loss: 0.6814 - val_accuracy: 0.5000
# Epoch 15/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6961 - accuracy: 0.5000 - val_loss: 0.6857 - val_accuracy: 0.7083
# Epoch 16/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6925 - accuracy: 0.5500 - val_loss: 0.6909 - val_accuracy: 0.5625
# Epoch 17/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6913 - accuracy: 0.5417 - val_loss: 0.6902 - val_accuracy: 0.6042
# Epoch 18/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6902 - accuracy: 0.5833 - val_loss: 0.6854 - val_accuracy: 0.6250
# Epoch 19/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6805 - accuracy: 0.6458 - val_loss: 0.6834 - val_accuracy: 0.5417
# Epoch 20/30
# 3/3 [==============================] - 2s 941ms/step - loss: 0.6810 - accuracy: 0.5417 - val_loss: 0.6785 - val_accuracy: 0.5833
# Epoch 21/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6827 - accuracy: 0.5208 - val_loss: 0.6215 - val_accuracy: 0.7917
# Epoch 22/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6737 - accuracy: 0.5208 - val_loss: 0.7024 - val_accuracy: 0.5625
# Epoch 23/30
# 3/3 [==============================] - 2s 655ms/step - loss: 0.7018 - accuracy: 0.5208 - val_loss: 0.6232 - val_accuracy: 0.6042
# Epoch 24/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6583 - accuracy: 0.6458 - val_loss: 0.6724 - val_accuracy: 0.6042
# Epoch 25/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6931 - accuracy: 0.5208 - val_loss: 0.6276 - val_accuracy: 0.5833
# Epoch 26/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6989 - accuracy: 0.6042 - val_loss: 0.6302 - val_accuracy: 0.7083
# Epoch 27/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6887 - accuracy: 0.5833 - val_loss: 0.6387 - val_accuracy: 0.6875
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6575 - accuracy: 0.6000 - val_loss: 0.6458 - val_accuracy: 0.5625
# Epoch 29/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6793 - accuracy: 0.5000 - val_loss: 0.6334 - val_accuracy: 0.7292
# Epoch 30/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6987 - accuracy: 0.4792 - val_loss: 0.6251 - val_accuracy: 0.7292

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(result.history.keys())
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('Model Accuracy- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['Train','Test'])
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model Loss- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend(['Train','Test'])
plt.show()

# %% [markdown]
# # 2. Build a multiclass classification model using CNN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPool2D
from keras import backend as k

# %%
batch_size=128
num_classes=10

# %%
img_rows,img_cols=28,28

# %%
from keras.datasets import mnist
(xtrain,ytrain),(xtest,ytest)=mnist.load_data()

# %%
print('Training set images shape: {}'.format(xtrain.shape))
print('Testing set images shape: {}'.format(xtest.shape))

print('Training set labels shape: {}'.format(ytrain.shape))
print('Testing set labels shape: {}'.format(ytest.shape))
# Out:
# Training set images shape: (60000, 28, 28)
# Testing set images shape: (10000, 28, 28)
# Training set labels shape: (60000,)
# Testing set labels shape: (10000,)

# %%
import matplotlib.pyplot as plt
plt.imshow(xtrain[5])

# %%
xtrain[0].shape
# Out:
# (28, 28)

# %%
#reshape data to fit model
xtrain=xtrain.reshape(xtrain.shape[0],img_rows,img_cols)
xtest=xtest.reshape(xtest.shape[0],img_rows,img_cols)

print(xtrain.shape)
print(xtest.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
xtrain=xtrain.astype('float32')
xtest=xtest.astype('float32')

# %%
xtrain/=255
xtest/=255

# %%
print('xtrain shape:',xtrain.shape)
print(xtrain.shape[0],'train samples')
print(xtest.shape[0],'test samples')
# Out:
# xtrain shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples

# %%
ytrain=keras.utils.to_categorical(ytrain)
ytest=keras.utils.to_categorical(ytest)

# %%
model = Sequential()

# Add model layers
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(28, 28, 1)))
model.add(Dropout(0.2))

model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 64)        640
#
#  dropout_2 (Dropout)         (None, 26, 26, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 32)        18464
#
#  max_pooling2d_6 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 10)                46090
#
# =================================================================
# Total params: 65194 (254.66 KB)
# Trainable params: 65194 (254.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
result=model.fit(xtrain,ytrain,batch_size=batch_size,
                epochs=3,verbose=1,
                validation_data=(xtest,ytest))
# Out:
# Epoch 1/3
# 469/469 [==============================] - 63s 128ms/step - loss: 0.2502 - accuracy: 0.9264 - val_loss: 0.0726 - val_accuracy: 0.9775
# Epoch 2/3
# 469/469 [==============================] - 64s 137ms/step - loss: 0.0728 - accuracy: 0.9783 - val_loss: 0.0473 - val_accuracy: 0.9848
# Epoch 3/3
# 162/469 [=========>....................] - ETA: 42s - loss: 0.0539 - accuracy: 0.9837

# %%
score=model.evaluate(xtest,ytest,verbose=0)
print('Test Loss:',score[0])
print()
print('Test accuracy',score[1])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(result.history.keys())
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('Model Accuracy- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['Train','Test'])
plt.show()

# %%
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model Loss- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend(['Train','Test'])
plt.show()
